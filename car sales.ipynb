# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Car_sales.csv')

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data.head(5)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.head(5)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
data['__year_resale_value'].fillna(data['__year_resale_value'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     2
# Engine_size            1
# Horsepower             1
# Wheelbase              1
# Width                  1
# Length                 1
# Curb_weight            2
# Fuel_capacity          1
# Fuel_efficiency        3
# Latest_Launch          0
# Power_perf_factor      2
# dtype: int64

# %%
data['Price_in_thousands'].fillna(data['Price_in_thousands'].mean(),inplace=True)
data['Engine_size'].fillna(data['Engine_size'].mean(),inplace=True)
data['Horsepower'].fillna(data['Horsepower'].mean(),inplace=True)
data['Wheelbase'].fillna(data['Wheelbase'].mean(),inplace=True)
data['Width'].fillna(data['Width'].mean(),inplace=True)
data['Length'].fillna(data['Length'].mean(),inplace=True)
data['Curb_weight'].fillna(data['Curb_weight'].mean(),inplace=True)
data['Fuel_capacity'].fillna(data['Fuel_capacity'].mean(),inplace=True)
data['Power_perf_factor'].fillna(data['Power_perf_factor'].mean(),inplace=True)
data['Fuel_efficiency'].fillna(data['Fuel_efficiency'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger           21.500000          1.8       140.0      101.2
# ...

# %%
data.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
data[data['Price_in_thousands']>50]
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 6           Audi              A8               1.380            39.000000
# 39         Dodge           Viper               0.916            58.470000
# 73         Lexus           LS400               6.375            40.375000
# 74         Lexus           LX470               9.126            18.072975
# 94    Mercedes-B         S-Class              16.774            50.375000
# 95    Mercedes-B        SL-Class               3.311            58.600000
# 99    Mercedes-B           CL500               0.954            18.072975
# 125      Porsche   Carrera Coupe               1.280            60.625000
# 126      Porsche  Carrera Cabrio               1.866            67.550000
# 144       Toyota    Land Cruiser               9.835            34.080000
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 6      Passenger              62.000          4.2       310.0      113.0
# ...

# %%
data[data['Price_in_thousands']<=120]
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919            16.360000
# 1          Acura       TL              39.384            19.875000
# 2          Acura       CL              14.114            18.225000
# 3          Acura       RL               8.588            29.725000
# 4           Audi       A4              20.397            22.255000
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545            18.072975
# 153        Volvo      S70              15.245            18.072975
# 154        Volvo      V70              17.531            18.072975
# 155        Volvo      C70               3.493            18.072975
# 156        Volvo      S80              18.969            18.072975
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger           21.500000          1.8       140.0      101.2
# ...

# %%
data.rename(columns = {'__year_resale_value':'year_resale_value'},inplace=True)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0          Acura  Integra              16.919          16.360000    Passenger
# 1          Acura       TL              39.384          19.875000    Passenger
# 2          Acura       CL              14.114          18.225000    Passenger
# 3          Acura       RL               8.588          29.725000    Passenger
# 4           Audi       A4              20.397          22.255000    Passenger
# ..           ...      ...                 ...                ...          ...
# 152        Volvo      V40               3.545          18.072975    Passenger
# 153        Volvo      S70              15.245          18.072975    Passenger
# 154        Volvo      V70              17.531          18.072975    Passenger
# 155        Volvo      C70               3.493          18.072975    Passenger
# 156        Volvo      S80              18.969          18.072975    Passenger
#
# ...

# %%
data[data.Manufacturer == 'Honda']
# Out:
#    Manufacturer     Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 57        Honda     Civic             199.685              9.850    Passenger
# 58        Honda    Accord             230.902             13.210    Passenger
# 59        Honda      CR-V              73.203             17.710          Car
# 60        Honda  Passport              12.855             17.525          Car
# 61        Honda   Odyssey              76.029             19.490          Car
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 57              12.885          1.6       106.0      103.2   67.1   175.1
# 58              15.350          2.3       135.0      106.9   70.3   188.8
# 59              20.550          2.0       146.0      103.2   68.9   177.6
# 60              26.600          3.2       205.0      106.4   70.4   178.2
# 61              26.000          3.5       210.0      118.1   75.6   201.2
#
# ...

# %%
data[data.Manufacturer=='BMW']
# Out:
#   Manufacturer Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 7          BMW  323i              19.747          18.072975    Passenger
# 8          BMW  328i               9.231          28.675000    Passenger
# 9          BMW  528i              17.527          36.125000    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 7               26.99          2.5       170.0      107.3   68.4   176.0
# 8               33.40          2.8       193.0      107.3   68.5   176.0
# 9               38.90          2.8       193.0      111.4   70.9   188.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 7        3.179           16.6             26.0     6/28/2011
# 8        3.197           16.6             24.0     1/29/2012
# 9        3.472           18.5             25.0      4/4/2011
#
#    Power_perf_factor
# 7          71.191207
# 8          81.877069
# 9          83.998724

# %%
HONDA = data[data.Manufacturer=='Honda']

# %%
plt.bar(HONDA['Price_in_thousands'],HONDA['Sales_in_thousands'],color='r')
plt.title('Honda cars sales 2012',fontsize=20)
plt.ylabel('sales in thousand',fontsize=10)
plt.xlabel('prices in thousand',fontsize=17)
plt.gcf().set_size_inches(8,8)
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(data['Manufacturer'],data['Price_in_thousands'],color='b')
plt.title('car-prices 2012',fontsize=20)
plt.ylabel('prices in thousands',fontsize=16)
plt.xlabel('manufacturer company',fontsize=16)
plt.gcf().set_size_inches(15,8)
plt.xticks(rotation=90)
plt.show()

# %%
HONDA['Sales_in_thousands']
# Out:
# 57    199.685
# 58    230.902
# 59     73.203
# 60     12.855
# 61     76.029
# Name: Sales_in_thousands, dtype: float64

# %%
HONDA
# Out:
#    Manufacturer     Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 57        Honda     Civic             199.685              9.850    Passenger
# 58        Honda    Accord             230.902             13.210    Passenger
# 59        Honda      CR-V              73.203             17.710          Car
# 60        Honda  Passport              12.855             17.525          Car
# 61        Honda   Odyssey              76.029             19.490          Car
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 57              12.885          1.6       106.0      103.2   67.1   175.1
# 58              15.350          2.3       135.0      106.9   70.3   188.8
# 59              20.550          2.0       146.0      103.2   68.9   177.6
# 60              26.600          3.2       205.0      106.4   70.4   178.2
# 61              26.000          3.5       210.0      118.1   75.6   201.2
#
# ...

# %%
plt.barh(HONDA['Model'],HONDA['Price_in_thousands'],color='r')
plt.title('cars-prices 2012',fontsize=20)
plt.ylabel('prices in thousands',fontsize=16)
plt.xlabel('model',fontsize=16)
plt.gcf().set_size_inches(12,4)
plt.show()

# %%
data['Manufacturer'].value_counts().head()
# Out:
# Dodge         11
# Ford          11
# Toyota         9
# Chevrolet      9
# Mercedes-B     9
# Name: Manufacturer, dtype: int64

# %%
x=data['Manufacturer'].head(10)
y=data['Sales_in_thousands'].head(10)
plt.pie(y,labels=x,autopct='%2.2f%%')
plt.gcf().set_size_inches(10,10)
plt.show()

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0          Acura  Integra              16.919          16.360000    Passenger
# 1          Acura       TL              39.384          19.875000    Passenger
# 2          Acura       CL              14.114          18.225000    Passenger
# 3          Acura       RL               8.588          29.725000    Passenger
# 4           Audi       A4              20.397          22.255000    Passenger
# ..           ...      ...                 ...                ...          ...
# 152        Volvo      V40               3.545          18.072975    Passenger
# 153        Volvo      S70              15.245          18.072975    Passenger
# 154        Volvo      V70              17.531          18.072975    Passenger
# 155        Volvo      C70               3.493          18.072975    Passenger
# 156        Volvo      S80              18.969          18.072975    Passenger
#
# ...

# %%
x=data['Manufacturer'].head(80)
y=data['Sales_in_thousands'].head(80)
plt.xlabel('Manufacturer-company',fontsize=16)
plt.ylabel('Sales_in_thousands',fontsize=16)
plt.scatter(x,y,color='k')
plt.gcf().set_size_inches(15,7)
plt.show()
